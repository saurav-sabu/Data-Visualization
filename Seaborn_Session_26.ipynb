# %%
import seaborn as sns
import numpy as np

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")

# %% [markdown]
# ## Categorical Plots
#
# ### Categorical Scatter Plot
#
# - Stripplot
# - Swarmplot
#
# ### Categorical Distribution Plots
#
# - Boxplot
# - Violinplot
#
# ### Categorical Estimate Plot -> for central tendency
#
# - Barplot
# - Pointplot
# - Countplot
#
# ### Figure level function -> `catplot`

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)

# %%
# strip plot
# axes level function

# %%
sns.stripplot(x="day",y="tip",data=tips)

# %%
sns.stripplot(x="day",y="total_bill",data=tips)

# %%
# jitter
sns.stripplot(x="day",y="total_bill",data=tips,jitter=False)

# %%
sns.catplot(x="day",y="tip",data=tips,kind="strip")

# %%
# jitter
sns.catplot(x="day",y="tip",data=tips,kind="strip",jitter=2)

# %%
# hue
sns.catplot(x="day",y="tip",data=tips,kind="strip",hue="sex")

# %%
# swarmplot

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="swarm")

# %%
# hue
sns.swarmplot(x="day",y="total_bill",data=tips,hue="sex")

# %% [markdown]
# ### Boxplot
#
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# ![image.png](data:image/png;base64,...)

# %%
sns.boxplot(x="sex",y="total_bill",data=tips)

# %%
sns.boxplot(x="day",y="total_bill",data=tips)

# %%
# hue
sns.catplot(x="day",y="total_bill",data=tips,kind="box",hue="sex")

# %%
# single

# %%
sns.boxplot(x="total_bill",data=tips)

# %%
# Violinplot (Boxplot + Kdeplot)

# %%
sns.violinplot(x="day",y="total_bill",data=tips)

# %%
# hue
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex")

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="violin")

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",split=True)

# %%
# barplot

# %%
sns.barplot(x="day",y="tip",data=tips)

# %%
sns.barplot(x="day",y="total_bill",data=tips)

# %%
sns.barplot(x="sex",y="total_bill",data=tips)

# %% [markdown]
# When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
# Remove errorbar
sns.catplot(x="sex",y="total_bill",data=tips,kind="bar",ci=None)

# %%
sns.barplot(x="sex",y="total_bill",data=tips,hue="smoker")

# %%
# estimator
sns.barplot(x="sex",y="total_bill",data=tips,hue="smoker",estimator=np.median)

# %%
sns.barplot(x="sex",y="total_bill",data=tips,hue="smoker",estimator=np.min)

# %%
# pointplot

# %%
sns.pointplot(x="sex",y="total_bill",data=tips)

# %%
sns.pointplot(x="sex",y="total_bill",data=tips,hue="smoker")

# %%
# countplot

# %%
sns.countplot(x="sex",data=tips)

# %%
# hue
sns.countplot(x="sex",data=tips,hue="day")

# %% [markdown]
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing a statistic for a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable

# %%
# faceting using catplot

# %%
sns.catplot(x="sex",y="total_bill",data=tips,col="smoker")

# %%
sns.catplot(x="sex",y="total_bill",data=tips,col="smoker",kind="box")

# %%
sns.catplot(x="sex",y="total_bill",data=tips,col="smoker",kind="box",row="time")

# %% [markdown]
# ### Regression Plots
#
# - regplot
# - lmplot
#
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
# regplot

# %%
sns.regplot(x="total_bill",y="tip",data=tips,color="red")

# %%
# hue parameter is not available
sns.regplot(x="total_bill",y="tip",data=tips,color="red")

# %%
# lmplot

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex")

# %%
# residplot

# %%
sns.residplot(x="total_bill",y="tip",data=tips)

# %%
# It does not have a hue parameter
sns.residplot(x="total_bill",y="tip",data=tips)

# %% [markdown]
# ### A second way to plot Facet plots -> FacetGrid

# %%
sns.catplot(x="sex",y="total_bill",data=tips,kind="violin")

# %% [markdown]
# # Traditional Way

# %%
sns.catplot(x="sex",y="total_bill",data=tips,kind="violin",col="sex",row="time")

# %% [markdown]
# ### FacetGrid

# %%
g = sns.FacetGrid(data=tips,col="day",row="time")
g.map(sns.violinplot,"sex","total_bill")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(data=tips,col="day",row="time")
g.map(sns.boxplot,"sex","total_bill")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(data=tips,col="day",row="time",hue="smoker")
g.map(sns.scatterplot,"sex","total_bill")
g.add_legend()

# %% [markdown]
# ### Plotting Pairwise Relationship (PairGrid Vs Pairplot)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue="species")

# %%
# pairgrid

# %%
g = sns.PairGrid(iris)
g.map(sns.scatterplot)

# %%
# map_diag -> map_offdiag
g = sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.violinplot)
g.map_offdiag(sns.scatterplot)

# %%
# pairgrid -> map_upper -> map_lower
g = sns.PairGrid(iris,hue="species")
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
# vars
g = sns.PairGrid(iris,hue="species",vars=["sepal_length","petal_width"])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %% [markdown]
# ### JointGrid Vs Jointplot

# %%
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="scatter")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hist")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hist",hue="sex")

# %%
g = sns.JointGrid(data = tips)
g.plot(sns.scatterplot,sns.histplot)

# %%
g = sns.JointGrid(data = tips[["total_bill","tip"]])
g.plot(sns.scatterplot,sns.histplot)

# %%
g = sns.JointGrid(data = tips[["total_bill","tip"]])
g.plot(sns.scatterplot,sns.boxplot)

# %% [markdown]
# ## Utility functions

# %%
# name of all the dataset
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# load the dataset
sns.load_dataset("flights")
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
